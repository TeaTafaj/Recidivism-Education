# %% [markdown]
# ## 1. Load Data
# Download the data from Google Drive using `gdown`, then read the csv file.

# %%
# Step 1: Install gdown (only need to do this once)
# !pip install gdown

# Step 2: Download and read the file
import gdown
import pandas as pd

file_id = "1jkBkjOsdr-0hhUgj3p2J7pk1Welkk7A1"
gdown.download(id=file_id, output="dataset.csv", quiet=False)

df = pd.read_csv("dataset.csv", sep="\t")
df.head()
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1jkBkjOsdr-0hhUgj3p2J7pk1Welkk7A1
# From (redirected): https://drive.google.com/uc?id=1jkBkjOsdr-0hhUgj3p2J7pk1Welkk7A1&confirm=t&uuid=01886b46-adb2-4cfd-8690-321450c59788
# To: /Users/ananyajogalekar/Library/CloudStorage/GoogleDrive-ananyajogalekar5@gmail.com/My Drive/Duke University/00-Coursework/github-finalprojects-local/Recidivism-Education/dataset.csv
# 100%|██████████| 976M/976M [00:34<00:00, 28.6MB/s]
#          ABT_INMATE_ID  SEX  ADMTYPE  OFFGENERAL  EDUCATION  ADMITYR  \
# 0  A012021000000090128    1        1           2          9     2013
# 1  A012021000000110168    1        1           1          9     2004
# 2  A012021000000090187    1        1           2          9     2009
# 3  A012021000000010425    1        3           3          9     2016
# 4  A012021000000090117    1        1           1          9     2009
#
#    RELEASEYR  MAND_PRISREL_YEAR  PROJ_PRISREL_YEAR  PARELIG_YEAR  SENTLGTH  \
# ...
